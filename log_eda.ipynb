# %%
import lasio
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pathlib

# %%
las_files = sorted(pathlib.Path("data").glob("*.las"))
las_files
# Out:
# [PosixPath('data/WELL_1.las'),
#  PosixPath('data/WELL_2.las'),
#  PosixPath('data/WELL_3.las'),
#  PosixPath('data/WELL_4.las'),
#  PosixPath('data/WELL_5.las'),
#  PosixPath('data/WELL_6.las')]

# %%
def plot_las(las_file):
    pass
for las_file in las_files:
    plot_las(las_file)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 19
#      17     plt.show()
#      18 for las_file in las_files:
# ---> 19     plot_las(las_file)
#
# Cell In[18], line 9, in plot_las(las_file)
#       7 for i, col in enumerate(cols):
#       8     if col != 'DEPTH':
# ----> 9         axes[i].plot(df.index, df[col], label=col)
#      10         axes[i].set_ylabel(col)
#      11         axes[i].legend()
#
# IndexError: index 3 is out of bounds for axis 0 with size 3
